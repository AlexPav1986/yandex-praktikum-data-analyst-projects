# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропусков" data-toc-modified-id="Обработка-пропусков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Обработка пропусков</a></span><ul class="toc-item"><li><span><a href="#столбец-is_apartment" data-toc-modified-id="столбец-is_apartment-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>столбец is_apartment</a></span></li><li><span><a href="#столбец-parks_nearest--и--ponds_nearest" data-toc-modified-id="столбец-parks_nearest--и--ponds_nearest-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>столбец parks_nearest  и  ponds_nearest</a></span></li><li><span><a href="#столбец-balcony" data-toc-modified-id="столбец-balcony-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>столбец balcony</a></span></li><li><span><a href="#столбец-ceiling_height" data-toc-modified-id="столбец-ceiling_height-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>столбец ceiling_height</a></span></li><li><span><a href="#столбцы-airports_nearest,-----city_centers_nearest,-parks_around_3000,-parks_nearest,-ponds_around_3000,-ponds_nearest" data-toc-modified-id="столбцы-airports_nearest,-----city_centers_nearest,-parks_around_3000,-parks_nearest,-ponds_around_3000,-ponds_nearest-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>столбцы airports_nearest,     city_centers_nearest, parks_around_3000, parks_nearest, ponds_around_3000, ponds_nearest</a></span></li><li><span><a href="#столбец-days_exposition" data-toc-modified-id="столбец-days_exposition-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>столбец days_exposition</a></span></li><li><span><a href="#столбцы-kitchen_area,-living_area" data-toc-modified-id="столбцы-kitchen_area,-living_area-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>столбцы kitchen_area, living_area</a></span></li><li><span><a href="#столбцы-floors_total,-locality_name" data-toc-modified-id="столбцы-floors_total,-locality_name-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>столбцы floors_total, locality_name</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Изменение типов данных</a></span><ul class="toc-item"><li><span><a href="#last_price" data-toc-modified-id="last_price-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>last_price</a></span></li><li><span><a href="#first_day_exposition" data-toc-modified-id="first_day_exposition-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>first_day_exposition</a></span></li><li><span><a href="#floors_total" data-toc-modified-id="floors_total-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>floors_total</a></span></li><li><span><a href="#airports_nearest-и-city_centers_nearest" data-toc-modified-id="airports_nearest-и-city_centers_nearest-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>airports_nearest и city_centers_nearest</a></span></li><li><span><a href="#ceiling_height" data-toc-modified-id="ceiling_height-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>ceiling_height</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-за-квадратный-метр" data-toc-modified-id="Цена-за-квадратный-метр-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Цена за квадратный метр</a></span></li><li><span><a href="#День-недели,-месяц-и-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц-и-год-публикации-объявления-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>День недели, месяц и год публикации объявления</a></span></li><li><span><a href="#Этаж-квартиры:-первый,-последний,-другой" data-toc-modified-id="Этаж-квартиры:-первый,-последний,-другой-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Этаж квартиры: первый, последний, другой</a></span></li><li><span><a href="#Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей" data-toc-modified-id="Соотношение-жилой-и-общей-площади,-а-также-отношение-площади-кухни-к-общей-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Соотношение жилой и общей площади, а также отношение площади кухни к общей</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучим-площадь,-цену,-число-комнат,-высоту-потолков-и-удаленность-от-центра" data-toc-modified-id="Изучим-площадь,-цену,-число-комнат,-высоту-потолков-и-удаленность-от-центра-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучим площадь, цену, число комнат, высоту потолков и удаленность от центра</a></span><ul class="toc-item"><li><span><a href="#Площадь-недвижимости" data-toc-modified-id="Площадь-недвижимости-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Площадь недвижимости</a></span></li><li><span><a href="#Цена-недвижимости" data-toc-modified-id="Цена-недвижимости-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Цена недвижимости</a></span></li><li><span><a href="#Число-комнат" data-toc-modified-id="Число-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Число комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Высота потолков</a></span></li><li><span><a href="#Удаленность-от-центра" data-toc-modified-id="Удаленность-от-центра-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Удаленность от центра</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Изучим-время-продажи-недвижимости" data-toc-modified-id="Изучим-время-продажи-недвижимости-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Изучим время продажи недвижимости</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Зачистка-данных.-Уберем-все-лишнее" data-toc-modified-id="Зачистка-данных.-Уберем-все-лишнее-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Зачистка данных. Уберем все лишнее</a></span></li><li><span><a href="#Населенные-пункты,-цены" data-toc-modified-id="Населенные-пункты,-цены-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Населенные пункты, цены</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Факторы,-влияющие-на-стоимоcть-квартиры" data-toc-modified-id="Факторы,-влияющие-на-стоимоcть-квартиры-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Факторы, влияющие на стоимоcть квартиры</a></span><ul class="toc-item"><li><span><a href="#Цена---площадь" data-toc-modified-id="Цена---площадь-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Цена - площадь</a></span></li><li><span><a href="#Цена---число-комнат" data-toc-modified-id="Цена---число-комнат-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Цена - число комнат</a></span></li><li><span><a href="#Цена---этаж-(первый-или-последний)" data-toc-modified-id="Цена---этаж-(первый-или-последний)-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>Цена - этаж (первый или последний)</a></span></li><li><span><a href="#Цена---удаленность-от-центра" data-toc-modified-id="Цена---удаленность-от-центра-4.6.4"><span class="toc-item-num">4.6.4&nbsp;&nbsp;</span>Цена - удаленность от центра</a></span></li><li><span><a href="#Цена---дата-размещения" data-toc-modified-id="Цена---дата-размещения-4.6.5"><span class="toc-item-num">4.6.5&nbsp;&nbsp;</span>Цена - дата размещения</a></span></li></ul></li><li><span><a href="#Квартиры-в-Санкт-Петербурге-и-в-его-центре" data-toc-modified-id="Квартиры-в-Санкт-Петербурге-и-в-его-центре-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Квартиры в Санкт-Петербурге и в его центре</a></span><ul class="toc-item"><li><span><a href="#Изучим-недвижимость-в-центре,-сравним-с-остальной-частью-города" data-toc-modified-id="Изучим-недвижимость-в-центре,-сравним-с-остальной-частью-города-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Изучим недвижимость в центре, сравним с остальной частью города</a></span><ul class="toc-item"><li><span><a href="#Площадь-центр---площадь-город" data-toc-modified-id="Площадь-центр---площадь-город-4.7.1.1"><span class="toc-item-num">4.7.1.1&nbsp;&nbsp;</span>Площадь центр - площадь город</a></span></li><li><span><a href="#Цена-центр---цена-город" data-toc-modified-id="Цена-центр---цена-город-4.7.1.2"><span class="toc-item-num">4.7.1.2&nbsp;&nbsp;</span>Цена центр - цена город</a></span></li><li><span><a href="#Число-комнат-центр---число-комнат-город" data-toc-modified-id="Число-комнат-центр---число-комнат-город-4.7.1.3"><span class="toc-item-num">4.7.1.3&nbsp;&nbsp;</span>Число комнат центр - число комнат город</a></span></li><li><span><a href="#Высота-потолков-центр---высота-потолков-город" data-toc-modified-id="Высота-потолков-центр---высота-потолков-город-4.7.1.4"><span class="toc-item-num">4.7.1.4&nbsp;&nbsp;</span>Высота потолков центр - высота потолков город</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#Факторы-влияния-на-цену-в-центре" data-toc-modified-id="Факторы-влияния-на-цену-в-центре-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Факторы влияния на цену в центре</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.7.4"><span class="toc-item-num">4.7.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# **Описание данных**
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# **ЦЕЛЬ**
# - Выявить основные параметры недвижимости, которые оказывают влияние на формирование цены.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# *Импортируем библиотеки*

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns

# %% [markdown]
# *Загрузим данные*

# %%
# используем разделитель колонок со значением '\t'

import os
if os.path.exists('real_estate_data.csv'):
    df = pd.read_csv('real_estate_data.csv', sep='\t') # локальный путь
else:
    df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') # путь указанный в проекте

# %% [markdown]
# *Сбросим ограничения на число столбцов*

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# *Выведем первые 5 строк*

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# *проверим наименовая колонок*

# %%
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# *приведем некоторые столбцы к 'змеиному' регистру*

# %%
df = df.rename(columns={
     'cityCenters_nearest':'city_centers_nearest',
     'parks_around3000':'parks_around_3000',
     'ponds_around3000':'ponds_around_3000'})

# %% [markdown]
# *Посмотрим на количество данных и тип столбцов*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# city_centers_nearest    18180 non-null float64
# parks_around_3000       18181 non-null float64
# ...

# %% [markdown]
# **В нашем распоряжении 23699 строк и 22 столбца. Большая часть столбцов имеет вещественный тип данных. Во многих столбцах имеются пропуски**

# %% [markdown]
# *Посмотрим на количество пропусков*

# %%
df.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# **Пропуски присутствуют в большей части датайфрейма: в среднем по 5000, но есть и более 10000**

# %% [markdown]
# *Проверим количество дубликатов*

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Хорошие новости: дубликатов нет**

# %% [markdown]
# ### Вывод

# %% [markdown]
# <div style="border:solid indigo 2px; padding: 20px">
#
# - Датафрейм состоит из 23699 строк и 22 столбцов
# - Несколько колонок переименовали, приведя к 'змеиному' регистру, для более удобного чтения
# - В основном данные датафрейма - это числовые значения, записанные в вещественном формате. Есть столбцы с булевыми значениями. Есть с датами, записанными как object.
# - Большинство столбцов имеют пропуски, в среднем 5000, но есть те, кто имеют порядка 80-90% пропусков
# - Дубликаты в датафрейме отсутствуют

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Обработка пропусков

# %% [markdown]
# *Посмотрим еще раз где и сколько в процентах у нас пропусков*

# %%
df.isna().mean().sort_values(ascending=False)
# Out:
# is_apartment            0.882906
# parks_nearest           0.659100
# ponds_nearest           0.615596
# balcony                 0.486054
# ceiling_height          0.387991
# airports_nearest        0.233850
# city_centers_nearest    0.232879
# parks_around_3000       0.232837
# ponds_around_3000       0.232837
# days_exposition         0.134225
# kitchen_area            0.096122
# living_area             0.080299
# floors_total            0.003629
# locality_name           0.002068
# first_day_exposition    0.000000
# last_price              0.000000
# total_area              0.000000
# studio                  0.000000
# rooms                   0.000000
# floor                   0.000000
# open_plan               0.000000
# total_images            0.000000
# dtype: float64

# %% [markdown]
# **Рассмотрим данные столбцы в порядке уменьшения количества пропусков**

# %% [markdown]
# #### столбец is_apartment

# %% [markdown]
# *имеет 88% пропусков*

# %%
df['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %%
df['is_apartment'].value_counts()[1] / df.shape[0]
# Out:
# 0.0021097936621798387

# %% [markdown]
#  <div style="border:solid black 1px; padding: 20px">
#
# **указано, что только 50 квартир являются апартаментами. 2725 - указали, что это не апартаменты.**
# - апартаменты относятся к коммерческой недвижимости. В основном покупают для инвестирования. Рынок таких продаж на порядок ниже продажи жилой площади. Согласно сайту яндекс недвижимости, доля апартаментов на рынке - 10-20%.
# - Сейчас в датафрейме 50 апартаментов - это меньше 1%. Поэтому нельзя сказать, что все пропуски - это жилая недвижимость или апартаменты.
# - Принято решение не заполнять пропуски.

# %% [markdown]
# #### столбец parks_nearest  и  ponds_nearest

# %% [markdown]
# *имеют 65% и 61% пропусков*

# %% [markdown]
# *проверим связь со столбцами parks_around_3000 и ponds_around_3000 (кол-во парков и прудов в радиусе 3км)*

# %%
df[['parks_around_3000','parks_nearest']].query('parks_around_3000 == 0').head()
# Out:
#     parks_around_3000  parks_nearest
# 1                 0.0            NaN
# 6                 0.0            NaN
# 7                 0.0            NaN
# 9                 0.0            NaN
# 11                0.0            NaN

# %%
df[['ponds_around_3000','ponds_nearest']].query('ponds_around_3000 == 0').head()
# Out:
#     ponds_around_3000  ponds_nearest
# 1                 0.0            NaN
# 6                 0.0            NaN
# 7                 0.0            NaN
# 9                 0.0            NaN
# 11                0.0            NaN

# %% [markdown]
#  <div style="border:solid black 1px; padding: 20px">
#
# **Пропуски в данных столбцах из-за отсутствия парков и водоемов по близости**
#
# - Если рядом нет парков и водоемов автоматически ставится пропуск
# - Это подтверждается столбцами с количеством парков и водоемов. Пропуски там, где нет парков и водоемов.
# - Принято решение не заполнять пропуски.

# %% [markdown]
# #### столбец balcony

# %% [markdown]
# *имеет 48% пропусков*

# %% [markdown]
# *заменим пропуски на 0*

# %%
df['balcony'] = df['balcony'].fillna(0)

# %% [markdown]
# *Проверим, какие теперь значения у нас в столбце*

# %%
df['balcony'].unique()
# Out:
# array([0., 2., 1., 5., 4., 3.])

# %% [markdown]
#  <div style="border:solid black 1px; padding: 20px">
#
# - Заменили пропуски на 0, тк если балконы не указаны, значит с большей доли вероятности их просто нет.

# %% [markdown]
# #### столбец ceiling_height

# %% [markdown]
# *имеет 38% пропусков*

# %% [markdown]
# *Посмотрим на самые частые высоты потолков*

# %%
df['ceiling_height'].value_counts().head(10)
# Out:
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1112
# 2.80     993
# 2.55     980
# 2.75     910
# 2.65     676
# 3.20     277
# 3.10     203
# Name: ceiling_height, dtype: int64

# %% [markdown]
# Подавляющая часть потолков от 2,5 до 3 метров. Давайте посмотрим из каких городов это недвижимость

# %%
df.query('2.5 <= ceiling_height <= 3')['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург      8670
# Всеволожск            267
# посёлок Шушары        216
# Пушкин                213
# посёлок Мурино        198
# Колпино               192
# Гатчина               143
# Петергоф              139
# посёлок Парголово     136
# Сестрорецк            123
# Name: locality_name, dtype: int64

# %% [markdown]
# **Большинство квартир с потолком от 2.5 до 3 метров расположены в Санкт-Петербурге**

# %% [markdown]
# *Проверим какое-нибудь условие с большим охватом параметров, сузится ли диапазон высот потолков*

# %%
df.query('locality_name == "Санкт-Петербург" and 0<airports_nearest<10000 and 0<last_price<=10000000')['ceiling_height'].unique()
# Out:
# array([2.77,  nan, 2.5 , 2.55, 2.65, 2.7 , 2.6 , 2.75, 3.  , 2.54, 2.66,
#        2.52, 2.8 , 3.1 , 2.73, 2.9 , 3.01, 3.07, 3.17, 2.87, 3.05, 2.51,
#        3.2 , 2.59, 2.47])

# %% [markdown]
# *Получили невероятный разброс высот. Нет смысла искать медианное или среднее, поскольку нет данных, чтобы найти один и тот же дом с одинаковой высотой потолков, предлагаю оставить пропуски. Да, это 38%, зато данные останутся фактическими.*

# %% [markdown]
#  <div style="border:solid black 1px; padding: 20px">
#
# - *Поскольку выявить зависимость между различными параметрами нет возможности, принято решение оставить пропуски.*

# %% [markdown]
# #### столбцы airports_nearest, 	city_centers_nearest, parks_around_3000, parks_nearest, ponds_around_3000, ponds_nearest

# %% [markdown]
# *имеют по 23% пропусков*

# %%
df[df['airports_nearest'].isnull()].head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 5             10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8             20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12            10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22            20   5000000.0       58.00  2017-04-24T00:00:00      2
# 30            12   2200000.0       32.80  2018-02-19T00:00:00      1
# 37            10   1990000.0       45.80  2017-10-28T00:00:00      2
# 38            10   3150000.0       40.00  2018-03-29T00:00:00      1
# 47            17   3600000.0       56.10  2018-10-18T00:00:00      3
# 60             3   2740000.0       35.00  2018-01-01T00:00:00      1
# 62             0   4800000.0       78.60  2017-09-17T00:00:00      3
#
#     ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 5              NaN          12.0        14.40      5          NaN   False
# ...

# %% [markdown]
#  <div style="border:solid black 1px; padding: 20px">
#
# **Данная недвижимость продается не в крупных городах, а в поселках и в деревнях, например в Мурино, Красный бор**
# - Судя по всему, там нет ни аэропортов, ни водоемов, ни парков. ((
# - Не будем заполнять пропуски.

# %% [markdown]
# #### столбец days_exposition

# %% [markdown]
# *имеет по 13% пропусков*

# %% [markdown]
#  <div style="border:solid black 1px; padding: 20px">
#
# **Данный столбец невозможно заполнить, не зная дату продажи**
# - Вероятно недвижимость с пропуском в данном столбце до сих пор висит в объявлениях о продаже.
# - Принято решение не заполнять пропуски.

# %% [markdown]
# #### столбцы kitchen_area, living_area

# %% [markdown]
# *имеют по ~ 1% пропусков*

# %% [markdown]
# #### столбцы floors_total, locality_name

# %% [markdown]
# *Сколько строк с пропусками в floors_total*

# %%
df['floors_total'].isnull().sum()
# Out:
# 86

# %% [markdown]
# *Сколько строк с пропусками в locality_name*

# %%
df['locality_name'].isnull().sum()
# Out:
# 49

# %% [markdown]
# *Угадывать в каком городе недвижимость или сколько этажей в здании не имеет смысла, строк с пропусками невероятно мало, поэтому удалим данные строки*

# %%
df = df.dropna(subset={'floors_total','locality_name'}).reset_index(drop=True)

# %% [markdown]
# *Проверим результат удаления*

# %%
df[['floors_total','locality_name']].isnull().sum()
# Out:
# floors_total     0
# locality_name    0
# dtype: int64

# %% [markdown]
#  <div style="border:solid black 1px; padding: 20px">
#
# - Столбцы имеют меньше 1% пропусков. Удалили данные пропуски, тк угадывать какой город или количество этажей нет смысла из-за малого количества строк

# %% [markdown]
# ### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# - **столбец is_apartment** указано, что только 50 квартир являются апартаментами. 2725 - указали, что это не апартаменты.
# Рынок продаж апартаментов на порядок ниже продажи жилой площади. Согласно сайту яндекс недвижимости, доля апартаментов на рынке 10-20%. В датафрейме число указанных апартаментов меньше 1%. Поэтому нельзя сказать, что все пропуски - это жилая недвижимость или наоборот. Принято решение - не заполнять пропуски.
# - **столбцы parks_nearest  и  ponds_nearest** имеют пропуски из-за отсутствия парков и водоемов по близости, автоматически ставится пропуск. Принято решение - не заполнять пропуски.
# - **столбец balcony** имеют пропуски из-за не указания наличия балкона. Принято решение - заменить пропуски на 0, тк если балконы не указаны, значит с большей доли вероятности их просто нет.
# - **столбец ceiling_height** имеет большой разброс высот в не зависимости от местонахождения, этажности, цены, принято решение оставить пропуски.
# - **столбцы airports_nearest, city_centers_nearest, parks_around_3000, parks_nearest, ponds_around_3000, ponds_nearest** с пропусками относятся к недвижимости, которая продается не в крупных городах, а в поселках и в деревнях, например в Мурино, Красный бор. Судя по всему, там нет ни аэропортов, ни водоемов, ни парков. Принято решение - не заполнять пропуски.
# - **столбец days_exposition** имеет пропуски, тк вероятно недвижимость в данном столбце до сих пор висит в объявлениях о продаже. Принято решение - не заполнять пропуски.
# - **столбцы kitchen_area, living_area** имеет большой разброс данных в не зависимости от местонахождения, этажности, цены, принято решение оставить пропуски, поскольку нет смысла выдумывать 1% данных.
# - **столбцы floors_total, locality_name** имеют меньше 1% пропусков. Угадывать какой город или количество этажей нет смысла из-за малого количества строк (86шт и 49шт). Принято решение - удалить строки с пропуски.

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# #### last_price

# %% [markdown]
# - Столбец имеет тип float64. Предлагаю таковым его и оставить.
# - Суммы представлены в млн. Предлагаю сократить количество знаков до одного целого и одного после запятой. Так будет легче читать суммы

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23565 entries, 0 to 23564
# Data columns (total 22 columns):
# total_images            23565 non-null int64
# last_price              23565 non-null float64
# total_area              23565 non-null float64
# first_day_exposition    23565 non-null object
# rooms                   23565 non-null int64
# ceiling_height          14481 non-null float64
# floors_total            23565 non-null float64
# living_area             21700 non-null float64
# floor                   23565 non-null int64
# is_apartment            2760 non-null object
# studio                  23565 non-null bool
# open_plan               23565 non-null bool
# kitchen_area            21343 non-null float64
# balcony                 23565 non-null float64
# locality_name           23565 non-null object
# airports_nearest        18041 non-null float64
# city_centers_nearest    18064 non-null float64
# parks_around_3000       18065 non-null float64
# ...

# %%
df['last_price'] = round(df['last_price'] / 1000000,1)

# %% [markdown]
# *Проверим результат*

# %%
df['last_price'].head()
# Out:
# 0    13.0
# 1     3.4
# 2     5.2
# 3    64.9
# 4    10.0
# Name: last_price, dtype: float64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - После уменьшения длины суммы, столбец со стоимостью квартир стало проще читать

# %% [markdown]
# #### first_day_exposition

# %% [markdown]
# *Столбец имеет тип object. Переведем его в тип datetime*

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'])

# %%
df['first_day_exposition'].head()
# Out:
# 0   2019-03-07
# 1   2018-12-04
# 2   2015-08-20
# 3   2015-07-24
# 4   2018-06-19
# Name: first_day_exposition, dtype: datetime64[ns]

# %%
df['first_day_exposition'].dt.day.head()
# Out:
# 0     7
# 1     4
# 2    20
# 3    24
# 4    19
# Name: first_day_exposition, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Столбец был переведен из типа object в тип datetime64. Теперь с ним можно производить различные манипуляции*

# %% [markdown]
# #### floors_total

# %%
df['floors_total'] = df['floors_total'].astype('int')

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Перевели столбец floors_total в целочисленные значения, тк количество этажей не может быть дробным

# %% [markdown]
# #### airports_nearest и city_centers_nearest

# %% [markdown]
# *Данные столбцы переведем в км для более легкого понимания расстояния*

# %%
df['airports_nearest'] = round(df['airports_nearest'] / 1000,1)

# %%
df['city_centers_nearest'] = round(df['city_centers_nearest'] / 1000,1)

# %%
df[['airports_nearest', 'city_centers_nearest']].head()
# Out:
#    airports_nearest  city_centers_nearest
# 0              18.9                  16.0
# 1              12.8                  18.6
# 2              21.7                  13.9
# 3              28.1                   6.8
# 4              31.9                   8.1

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - После перевода из метров в км стало более проще читать данные в столбцах

# %% [markdown]
# #### ceiling_height

# %% [markdown]
# *Переведем столбец в вещественный тип, тк высоты потолков - вещественные числа.*

# %%
df['ceiling_height'] = df['ceiling_height'].astype('float')

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - *После перевода столбца в вещественные значения с ним можно совершать математические действия*

# %% [markdown]
# ### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# - **Столбец last_price** имеет тип float64. Предлагаю таковым его и оставить. Суммы представлены в млн. Сократим количество знаков до одного целого и одного после запятой, чтобы легче читать суммы.
# - **Столбец first_day_exposition** имеет тип object. Переведем его в тип datetime для возможности работать с датами.
# - **Столбец floors_total** перевели в целочисленные значения, тк количество этажей не может быть дробным.
# - **Столбцы airports_nearest и city_centers_nearest** перевели в км для упрощения чтения данных в столбцах.
# - **Столбец ceiling_height** имеет тип object. Перевели в вещественные значения, тк высоты потолков - вещественные числа. Теперь с данными можно совершать математические действия.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Цена за квадратный метр

# %% [markdown]
# *Добавим в данные цену квадратного метра в тысячах*

# %%
df['price_per_sqm'] = round(df['last_price'] / df['total_area'] *1000, 1)

# %%
df[['last_price', 'total_area', 'price_per_sqm']].head()
# Out:
#    last_price  total_area  price_per_sqm
# 0        13.0       108.0          120.4
# 1         3.4        40.4           84.2
# 2         5.2        56.0           92.9
# 3        64.9       159.0          408.2
# 4        10.0       100.0          100.0

# %%
df['price_per_sqm'].describe()
# Out:
# count    23565.000000
# mean        99.438430
# std         50.392112
# min          0.000000
# 25%         76.600000
# 50%         95.000000
# 75%        114.300000
# max       1907.500000
# Name: price_per_sqm, dtype: float64

# %%
df.query('price_per_sqm == 0')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8750             7         0.0       109.0           2019-03-20      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 8750            2.75            25         32.0     25          NaN   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 8750      False          40.5      0.0  Санкт-Петербург              36.4
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 8750                   9.2                1.0          805.0
#
#       ponds_around_3000  ponds_nearest  days_exposition  price_per_sqm
# 8750                0.0            NaN              8.0            0.0

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Медианное значение отличается от среднего ненамного, но имеем высокое стандартное отклонение 50тыс за м2, что говорит о больших выбросах. Также есть одна строчка с нулевым значением цены
# - Средняя цена квадратного метра составляет 99 тыс руб

# %% [markdown]
# ### День недели, месяц и год публикации объявления

# %% [markdown]
# *Создадим колонку с годом публикации*

# %%
df['year_exposition_first'] = df['first_day_exposition'].dt.year

# %% [markdown]
# *Создадим колонку с месяцем публикации*

# %%
df['month_exposition_first'] = df['first_day_exposition'].dt.month

# %% [markdown]
# *Создадим колонку с днем публикации*

# %%
df['day_exposition_first'] = df['first_day_exposition'].dt.weekday_name

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Теперь, в случае необходимости, можно делать выборку отдельно по дням, месяцам и годам

# %% [markdown]
# ### Этаж квартиры: первый, последний, другой

# %% [markdown]
# *Категоризируем этаж недвижимости на три категории: первый, последний, другой*

# %%
def floor(row):
    
    # функция возвращает категорию этажа
    # первый, последний или другой
    
    if row['floor'] == 1:
        return 'первый'
    elif row['floors_total'] == row['floor']:
        return 'последний' 
    return 'другой'

# %%
df['floor_flat'] = df.apply(floor, axis=1)

# %%
df[['floors_total', 'floor', 'floor_flat']].head()
# Out:
#    floors_total  floor floor_flat
# 0            16      8     другой
# 1            11      1     первый
# 2             5      4     другой
# 3            14      9     другой
# 4            14     13     другой

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - *Получили столбец с тремя категориями этажа. Так проще искать квартиру*

# %% [markdown]
# ### Соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
df.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20        13.0       108.0           2019-03-07      3
# 1             7         3.4        40.4           2018-12-04      1
# 2            10         5.2        56.0           2015-08-20      2
# 3             0        64.9       159.0           2015-07-24      3
# 4             2        10.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16         51.0      8          NaN   False
# 1             NaN            11         18.6      1          NaN   False
# 2             NaN             5         34.3      4          NaN   False
# 3             NaN            14          NaN      9          NaN   False
# 4            3.03            14         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# *Узнаем, какое отношении жилой площади к площади квартиры*

# %%
df['part_living_area'] = round(df['living_area'] / df['total_area'], 2)

# %%
df['part_kitchen_area'] = round(df['kitchen_area'] / df['total_area'], 2)

# %%
df['part_living_area'].describe()
# Out:
# count    21700.000000
# mean         0.564916
# std          0.105372
# min          0.020000
# 25%          0.500000
# 50%          0.570000
# 75%          0.640000
# max          1.000000
# Name: part_living_area, dtype: float64

# %%
df['part_kitchen_area'].describe()
# Out:
# count    21343.000000
# mean         0.187306
# std          0.073083
# min          0.030000
# 25%          0.130000
# 50%          0.170000
# 75%          0.230000
# max          0.790000
# Name: part_kitchen_area, dtype: float64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Медианное и среднее значения отношения жилой площади к общей почти совпали. Стандартное отклонение мало. Что говорит о том, что в данных минимальные выбросы. В среднем жилая площадь занимает 56% от общей площади квартиры.
# - Медианное и среднее значения отношения площади кухни к общей почти совпали. Стандартное отклонение мало. Что говорит о том, что в данных минимальные выбросы. В среднем площадь кухни занимает 18% от общей площади квартиры.

# %% [markdown]
# ### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# - **Цена за квадратный метр**. После добавления столбца выяснили, что медианное значение отличается от среднего ненамного, но имеем высокое стандартное отклонение 50тыс за м2, что говорит о больших выбросах. Также есть одна строчка с нулевым значением цены. Средняя цена квадратного метра, составляет 99 тыс руб.
# - **День недели, месяц и год публикации объявления**. Добавили три столбца. Теперь, в случае необходимости, можно делать выборку отдельно по дням, месяцам и годам
# - **Этаж квартиры: первый, последний, другой**. Провели категоризацию столбца. Получили столбец с тремя категориями этажа. Теперь искать недвижимость будет легче.
# - **Соотношение жилой и общей площади, а также отношение площади кухни к общей**. Добавили два столбца. Медианное и среднее значения отношения жилой площади к общей почти совпали. Стандартное отклонение мало. Что говорит о том, что в данных минимальные выбросы. В среднем жилая площадь занимает 56% от общей площади квартиры. Медианное и среднее значения отношения площади кухни к общей почти совпали. Стандартное отклонение мало. Что говорит о том, что в данных минимальные выбросы. В среднем площадь кухни занимает 18% от общей площади квартиры.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучим площадь, цену, число комнат, высоту потолков и удаленность от центра

# %% [markdown]
# #### Площадь недвижимости

# %% [markdown]
# *Взглянем на описание данных в столбце*

# %%
df['total_area'].describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# *Стандартное отклонение 35, это говорит о наличие выбросов. Также у нас среднее отличается от медианного значения на 12.*

# %% [markdown]
# *Построим гистограмму*

# %%
df['total_area'].hist()
plt.title('total_area')
plt.xlabel('Площадь квартиры')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по м2');
plt.show()

# %% [markdown]
# **Основные данные сконцентрированы в области от 12 (минимальное значение) до 200.**

# %% [markdown]
# *Изменим диапазон диаграммы и увеличим число корзин*

# %%
df['total_area'].hist(range=(12,200), bins=200)
plt.title('total_area')
plt.xlabel('Площадь квартиры')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по м2');
plt.show()

# %% [markdown]
# *Построим диаграмму размаха и еще раз посмотрим на выбросы*

# %%
sns.boxplot(df['total_area'])
plt.xlim(0, 150)
plt.xlabel('Площадь квартиры')
plt.title('Распределение квартир по м2')
plt.show();

# %% [markdown]
# *Точки справа полутора межквартильного размаха слились в сплошную линию, что говорит об громном количестве выбросов. Медиана больше стремиттся к левому 'усу', значит данные меньше медианы - более частые, а выбросы справа 'уса' - более редкие*

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Необходимо использовать данные в срезе от 12 до 120 м2. Так как данные вне этого диапазона - это выбросы, которые могут исказить результат.

# %% [markdown]
# #### Цена недвижимости

# %% [markdown]
# *Взглянем на описание данных в столбце*

# %%
df['last_price'].describe()
# Out:
# count    23565.000000
# mean         6.541634
# std         10.910834
# min          0.000000
# 25%          3.400000
# 50%          4.600000
# 75%          6.800000
# max        763.000000
# Name: last_price, dtype: float64

# %% [markdown]
# *Имеется нулевое значение цены, удивительная щедрость. Среднее больше медианного и большое стандартное отклонение - есть выбросы*

# %%
df.query('last_price == 0')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8750             7         0.0       109.0           2019-03-20      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 8750            2.75            25         32.0     25          NaN   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 8750      False          40.5      0.0  Санкт-Петербург              36.4
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 8750                   9.2                1.0          805.0
#
#       ponds_around_3000  ponds_nearest  days_exposition  price_per_sqm  \
# 8750                0.0            NaN              8.0            0.0
#
#       year_exposition_first  month_exposition_first day_exposition_first  \
# 8750                   2019                       3            Wednesday
#
#      floor_flat  part_living_area  part_kitchen_area
# ...

# %% [markdown]
# *Всего одна запись с нулевым значением, не будем ее учитывать*

# %%
df['last_price'].hist()
plt.title('last_price')
plt.xlabel('Стоимость квартиры')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по цене');
plt.show()

# %% [markdown]
# *На данном графике видно, что основная недвижимость в диапазоне от 0 до 100*

# %%
df['last_price'].hist(range=(0.1,100), bins=50)
plt.title('last_price')
plt.xlabel('Стоимость квартиры')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по цене');
plt.show()

# %% [markdown]
# *Теперь стало яснее, что основная масса у нас от 0.1 до 20 млн*

# %%
df['last_price'].hist(range=(0.1,20), bins=100)
plt.title('last_price')
plt.xlabel('Стоимость квартиры')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по цене')
plt.show()

# %% [markdown]
# *Построим диаграмму размаха и еще раз посмотрим на выбросы*

# %%
sns.boxplot(df['last_price'])
plt.xlim(-1, 20)
plt.xlabel('Стоимость квартиры')

plt.title('Распределение квартир по цене')
plt.show();

# %% [markdown]
# *Точки справа полутора межквартильного размаха слились в сплошную линию, что говорит об громном количестве выбросов. Медиана больше стремиттся к левому 'усу', значит данные меньше медианы - более частые, а выбросы справа 'уса' - более редкие*

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Необходимо использовать данные в срезе от 0.1 до 12.5 млн. Так как данные вне этого диапазона - это выбросы, которые могут исказить результат.

# %% [markdown]
# #### Число комнат

# %%
df['rooms'].describe()
# Out:
# count    23565.000000
# mean         2.070656
# std          1.078591
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# *Стандартное отклонение почти равно 1, среднее и медианное значения почти равны. Это говорит о том, что разброс данных невелик.*

# %%
df['rooms'].hist()
plt.title('rooms')
plt.xlabel('Число комнат')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по количеству комнат')
plt.show()

# %% [markdown]
# *Большинство комнат в разрезе от 0 до 8. Выделим этот диапазон*

# %%
df['rooms'].hist(range=(0,8), bins=20)
plt.title('rooms')
plt.xlabel('Число комнат')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по количеству комнат')
plt.show()

# %%
df['rooms'].value_counts().head()
# Out:
# 1    8004
# 2    7897
# 3    5779
# 4    1172
# 5     325
# Name: rooms, dtype: int64

# %% [markdown]
# *Построим диаграмму размаха и еще раз посмотрим на выбросы*

# %%
sns.boxplot(df['rooms'])
plt.xlim(-1, 8)
plt.xlabel('Число комнат')

plt.title('Распределение квартир по количеству комнат')
plt.show();

# %% [markdown]
# *Основное количество комнат  - это 1, 2, 3*

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Необходимо использовать данные в срезе от 0 до 6 комнат, остальные данные  - выбросы, редкие значения

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Также мы можем увеличить сам график, чтобы его было удобнее изучать с помощью метода `plt.figure(figsize=(10,7))` или если используешь методы библиотеки `pandas`, в основном всегда есть атрибут `figsize=(10,7)`, который также поможет настроить ширину и высоту графика.
#
# </div>

# %% [markdown]
# #### Высота потолков

# %%
df['ceiling_height'].describe()
# Out:
# count    14481.000000
# mean         2.771283
# std          1.261983
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# *Высота 100м ? Может какой то склад.   Среднее почти равно медианному и невысокое стандартное отклонение. Есть несколько выбросов, например 100 можно будет сразу откинуть*

# %%
df['ceiling_height'].hist()
plt.title('ceiling_height')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по высоте потолков')
plt.show()

# %% [markdown]
# *Уменьшим диапазон*

# %%
df['ceiling_height'].hist(range=(2,10), bins=20)
plt.title('ceiling_height')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по высоте потолков')
plt.show()

# %% [markdown]
# *Высота более 4.5м уже не играет особой роли для анализа данных, тк это уже выбросы*

# %%
df['ceiling_height'].hist(range=(2,4.5), bins=50)
plt.title('ceiling_height')
plt.xlabel('Высота потолков')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по высоте потолков')
plt.show()

# %% [markdown]
# *Построим диаграмму размаха и еще раз посмотрим на выбросы*

# %%
sns.boxplot(df['ceiling_height'])
plt.xlim(0, 4)
plt.xlabel('Высота потолков')

plt.title('Распределение квартир по высоте потолков')
plt.show();

# %% [markdown]
# *До 2,2м имеются редкие выбросы, небольшое количество. Основная масса выбросов с высотой потолков более 3,5м.*

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Необходимо использовать данные в срезе от 2.2 до 3.5 м, остальные данные  - выбросы, редкие значения

# %% [markdown]
# #### Удаленность от центра

# %%
df['city_centers_nearest'].describe()
# Out:
# count    18064.000000
# mean        14.192621
# std          8.612953
# min          0.200000
# 25%          9.200000
# 50%         13.100000
# 75%         16.300000
# max         66.000000
# Name: city_centers_nearest, dtype: float64

# %% [markdown]
# *Расстояние от центра раскидано прилично, стандартное отклонение 8 км.*

# %%
df['city_centers_nearest'].hist(bins=100)
plt.title('city_centers_nearest')
plt.xlabel('Удаленность от центра, км')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по удаленности от центра')
plt.show()

# %%
df['city_centers_nearest'].hist(range=(30,40),bins=100)
plt.title('city_centers_nearest')
plt.xlabel('Удаленность от центра, км')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по удаленности от центра')
plt.show()

# %%
df['city_centers_nearest'].hist(range=(40,60),bins=100)
plt.title('city_centers_nearest')
plt.xlabel('Удаленность от центра, км')
plt.ylabel('Количество квартир')
plt.title('Распределение квартир по удаленности от центра')
plt.show()

# %% [markdown]
# *Основное распределение недвижимости в радиусе от 0,2 до 36 км от центра. Есть небольшое количество на расстоянии в 50км, но этот всплеск незначителен.*

# %% [markdown]
# *Построим диаграмму размаха и еще раз посмотрим на выбросы*

# %%
sns.boxplot(df['city_centers_nearest'])
plt.xlim(-1, 30)
plt.xlabel('Удаленность от центра, км')

plt.title('Распределение квартир по удаленности от центра')
plt.show();

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Необходимо использовать данные в срезе от 0 до 28 км, остальные данные  - выбросы, редкие значения

# %% [markdown]
# ### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# - **Данные по площади недвижимости** имеют серьезные выбросы, тк стандартное отклонение имеет высокое значение (35м2) и среднее отличается от медианного на 12 м2. Согласно построенной гистограмме необходимо уменьшить диапазон рассмотрения данных в отрезок от 12 (минимальное значение) до 120 м2, чтобы не учитывать большие выбросы.
# - **Данные по цене недвижимости** имеют выброс, тк стандартное отклонение имеет высокое значение (10млн) и среднее отличается от медианного на 2 млн. Согласно построенной гистограмме необходимо уменьшить диапазон рассмотрения данных в отрезок от 0.1 до 12.5 млн, чтобы не учитывать большие выбросы.
# - **Данные по числу комнат** имеют стандартное отклонение почти равно 1, среднее и медианное значения почти равны. Это говорит о том, что разброс данных невелик. Согласно полученной гистограмме сократим диапазон до отрезка от 0 до 6, убрав редкие данные.
# - **Данные по высоте потолков** имеют среднее почти равно медианному и невысокое стандартное отклонение. Есть несколько выбросов, например 100м, его можно будет откинуть. Согласно полученной гистограмме уменьшим диапазон до отрезка от 2.2 до 3.5м, убрав редки данные.
# - **Данные по удаленности от центра** имеют среднее отличное от медианного и  стандартное отклонение 8 км, прилично. Есть много выбросов, поэтому выбран диапазон от 0 до 28 км.

# %% [markdown]
# ### Изучим время продажи недвижимости

# %% [markdown]
# *Посмотрим на топ-10 самых быстрых сделок по недвижимости*

# %%
df['days_exposition'].sort_values().head(10)
# Out:
# 1627     1.0
# 15964    2.0
# 12987    2.0
# 16123    2.0
# 5668     3.0
# 22985    3.0
# 8760     3.0
# 22002    3.0
# 23013    3.0
# 12390    3.0
# Name: days_exposition, dtype: float64

# %% [markdown]
# *Взяглянем на 1 день и на 2 дня*

# %%
df.query('days_exposition == 1')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 1627            19         4.0        49.9           2019-05-01      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 1627             2.5             9         25.0      1          NaN   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 1627      False          10.0      0.0  Санкт-Петербург              13.6
#
#       city_centers_nearest  parks_around_3000  parks_nearest  \
# 1627                  14.4                1.0           20.0
#
#       ponds_around_3000  ponds_nearest  days_exposition  price_per_sqm  \
# 1627                1.0          681.0              1.0           80.2
#
#       year_exposition_first  month_exposition_first day_exposition_first  \
# 1627                   2019                       5            Wednesday
#
#      floor_flat  part_living_area  part_kitchen_area
# ...

# %% [markdown]
# *Однокомнатная квартирка в Санкт-Петербурге в 14км от центра рядом с парком за 4 млн. Купили как горячий пирожок*

# %%
df.query('days_exposition == 2')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 12987            20         6.1        51.4           2019-04-29      2
# 15964             4         4.1        45.1           2019-04-30      2
# 16123             0         7.8        25.0           2019-04-30      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 12987             3.0             5         31.7      4          NaN   False
# 15964             NaN             5         22.7      3          NaN   False
# 16123             3.0             5          NaN      5        False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 12987      False           6.9      1.0  Санкт-Петербург              10.8
# 15964      False           6.6      0.0  Санкт-Петербург              40.9
# 16123      False           NaN      0.0  Санкт-Петербург              36.5
#
# ...

# %% [markdown]
# * Три квартиры продали за 2 дня в 5ти этажных домах Санкт-Петербурга*

# %% [markdown]
# *Посмотрим на статистику по данным*

# %%
df['days_exposition'].describe()
# Out:
# count    20394.000000
# mean       180.741395
# std        219.732782
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# **Имеем огромное стандартное отклонение и отличие медианы от среднего в 2 раза. Это говорит нам о больших выбросах. Большой размах времени продажи от 1 дня до 4 лет**

# %% [markdown]
# *Посмотрим на количество уникальных дней продаж*

# %%
df['days_exposition'].value_counts().head()
# Out:
# 45.0    879
# 60.0    538
# 7.0     234
# 30.0    208
# 90.0    200
# Name: days_exposition, dtype: int64

# %% [markdown]
# *Построим гистограмму*

# %%
df['days_exposition'].hist()

plt.xlabel('Количество дней')
plt.ylabel('Количество сделок')
plt.title('Распределение продаж по количеству дней')
plt.show()

# %% [markdown]
# *Уменьшим диапазон до отрезка от 0 до 500 дней*

# %%
df['days_exposition'].hist(range=(0,500), bins=100)

plt.xlabel('Количество дней')
plt.ylabel('Количество сделок')
plt.title('Распределение продаж по количеству дней')
plt.show()

# %% [markdown]
# *Всплеск до 1200 не является правдой, тк самое большое число у нас это 879 продаж для 45 дней. Нужно уменьшить диапазон и увеличить число корзин*

# %%
df['days_exposition'].hist(range=(0,150), bins=150)

plt.xlabel('Количество дней')
plt.ylabel('Количество сделок')
plt.title('Распределение продаж по количеству дней')
plt.show()

# %%
df['days_exposition'].hist(range=(150,300), bins=150)

plt.xlabel('Количество дней')
plt.ylabel('Количество сделок')
plt.title('Распределение продаж по количеству дней')
plt.show()

# %% [markdown]
# *Посмотрим на медленные продажи*

# %%
df['days_exposition'].hist(range=(500,650), bins=150)
plt.xlabel('Количество дней')
plt.ylabel('Количество сделок')
plt.title('Распределение продаж по количеству дней')
plt.show()

# %% [markdown]
# *Построим диаграмму размаха и еще раз посмотрим на выбросы*

# %%
sns.boxplot(df['days_exposition'])
plt.xlim(-10, 600)
plt.xlabel('Количество дней')

plt.title('Распределение продаж по количеству дней')
plt.show();

# %% [markdown]
# *время более 500 дней - это уже выбросы*

# %% [markdown]
# #### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# - Обычно продажа недвижимости не затягивается дольше 220 дней, когда продажи падают меньше 30 в сутки.
# - **Быстрые продажи** - это продажи от 1 до 100 дней. Основная масса продаж пришлась именно на этот отрезок времени. Особенно часто продают за 45 (879 продаж) и за 60 дней (538 продаж). Возможно такое время продажи связано с закрытием квартала и срочной необходимостью закрыть сделку.
# - **Долгие продажи** - это продажи по прошествию 1,3 лет, 500 дней. Количество таких сделок уже не превышает 15 шт.

# %% [markdown]
# ### Зачистка данных. Уберем все лишнее

# %% [markdown]
# *Построенные гистограммы ранее помогут нам отбросить все выбросы и получить реалистичные данные для анализа*

# %% [markdown]
# **Выборку будем делать по столбцам:**
# - Площадь недвижимости: от 12 до 120
# - Цена недвижимости: от 0.1 до 12.5 млн
# - Число комнат: от 0 до 6 комнат
# - Высота потолков: от 2.2 до 3.5 м
# - Дни продажи: от 1 до 500 дней
# - Удаленность от центра: от 0 до 28 км

# %%
df_clean = df.query('12 <= total_area <= 120 \
                    and 0.1 <= last_price <= 12.5 \
                    and 0  <= rooms <= 6 \
                    and 2.2 <= ceiling_height <= 3.5 \
                    and 1 <= days_exposition <= 500 \
                    and 0 <= city_centers_nearest <= 28')

# %%
df_clean.shape[0]
# Out:
# 7117

# %%
df.shape[0]
# Out:
# 23565

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# После сокращения датафрейма согласно нашим условиям (исключение редких данных и выбросов), остался датафрейм, который в 3 раза меньше исходного. Зато ничего лишнего.

# %% [markdown]
# ### Населенные пункты, цены

# %%
df_clean.head()
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 4              2        10.0       100.0           2018-06-19      2
# 9             18         5.4        61.0           2017-02-26      3
# 10             5         5.0        39.6           2017-11-16      1
# 16            11         6.7        82.0           2017-11-23      3
# 18             8         3.2        31.0           2017-01-27      1
#
#     ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 4             3.03            14         32.0     13          NaN   False
# 9             2.50             9         43.6      7          NaN   False
# 10            2.67            12         20.3      3          NaN   False
# 16            3.05             5         55.6      1          NaN   False
# 18            2.50             5         19.4      2          NaN   False
#
#     open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# *Посмотрим на 10 населенных пунктов с наибольшим количеством продаж недвижимости*

# %%
df_clean['locality_name'].value_counts().head(10)
# Out:
# Санкт-Петербург         6780
# посёлок Парголово        115
# посёлок Шушары            85
# Пушкин                    80
# посёлок Металлострой      36
# посёлок Стрельна          19
# посёлок Песочный           2
# Name: locality_name, dtype: int64

# %% [markdown]
# **Чем крупнее населенный пункт, тем больше и продаж**

# %% [markdown]
# *Создадим сводную таблицу и подсчитаем среднее значение цены в ТОП-10 городах по продажам*

# %%
df_clean_town_pivot = df_clean.pivot_table(index='locality_name',
                                           values='price_per_sqm',
                                           aggfunc=['mean', 'count'])

# %%
df_clean_town_pivot.columns=['price_per_sqm_mean', 'price_per_sqm_count']

# %%
df_clean_town_pivot.sort_values('price_per_sqm_count', ascending=False)
# Out:
#                       price_per_sqm_mean  price_per_sqm_count
# locality_name
# Санкт-Петербург               105.323805                 6780
# посёлок Парголово              89.671304                  115
# посёлок Шушары                 81.435294                   85
# Пушкин                        100.075000                   80
# посёлок Металлострой           72.383333                   36
# посёлок Стрельна               89.152632                   19
# посёлок Песочный               88.600000                    2

# %% [markdown]
# *Отсортируем по средней цене*

# %%
df_clean_town_pivot.sort_values('price_per_sqm_mean', ascending=False)
# Out:
#                       price_per_sqm_mean  price_per_sqm_count
# locality_name
# Санкт-Петербург               105.323805                 6780
# Пушкин                        100.075000                   80
# посёлок Парголово              89.671304                  115
# посёлок Стрельна               89.152632                   19
# посёлок Песочный               88.600000                    2
# посёлок Шушары                 81.435294                   85
# посёлок Металлострой           72.383333                   36

# %% [markdown]
# #### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# - **Санкт-Петербург** - 1е место как по количеству продаж, так и по средней цене. Самый крупный город в топе, отсюда и высокая цена.
# - **Пушкин** - 2е место по цене, хотя по количеству сделок - на 4м. Высокие цены связаны с тем, что город ключён в список памятников, охраняемых ЮНЕСКО. Туристический центр.
# - **Шушары и Металлострой** - самая низкая средняя цена недвижимости. *Металлострой* - поселок с населением чуть более 30 тыс, который имеет более 20 заводов. Больше ничего там и нет. *Шушары* - в 2014 пришли крупные застройщики, выросли многоэтажки, без качественной социальной инфраструктуры, транспортной доступности. В основном строят социальное жилье, что влияет на криминогенную обстановку. Отсюда и невысокая средняя стоимость недвижимости.

# %% [markdown]
# ### Факторы, влияющие на стоимоcть квартиры

# %% [markdown]
# #### Цена - площадь

# %% [markdown]
# *Найдем коэффициент корреляции*

# %%
df_clean['total_area'].corr(df_clean['last_price'])
# Out:
# 0.804454713458526

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# Коэффициент 0,8 говорит нам о высокой связи данных. Чем больше площадь, тем больше и цена, все логично

# %% [markdown]
# #### Цена - число комнат

# %%
df_clean['rooms'].corr(df_clean['last_price'])
# Out:
# 0.5220406696876992

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# Коэффициент 0,52 говорит нам о наличи связи данных, но зависимость не прямая. Чем больше комнат, тем больше и цена, но есть отдельные квартиры с меньшим количеством комнат, но с большей стоимостью.

# %% [markdown]
# #### Цена - этаж (первый или последний)

# %% [markdown]
# *Сделаем сводную таблицу категоризированного этажа квартиры и цены*

# %%
df_clean_floor_flat_pivot = df_clean.pivot_table(index='floor_flat',
                                                 values='last_price',
                                                 aggfunc=['median','count'])

# %%
df_clean_floor_flat_pivot
# Out:
#                median      count
#            last_price last_price
# floor_flat
# другой            5.0       5505
# первый            4.5        787
# последний         5.0        825

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# Недвижимость на первом и последнем этажах покупают реже в 6 раз. Последний этаж более предпочтительнее первого. Первый этаж всегда считался хуже остальных: решетки на окнах, люди под окнами, под полом подвал, кошмар

# %% [markdown]
# #### Цена - удаленность от центра

# %%
df_clean['city_centers_nearest'].corr(df_clean['last_price'])
# Out:
# -0.3610992967806248

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# Присутствует небольшая отрицательная связь расположения недвижимости по отношению к центру города и ценой. Чем меньше расстояние от центра (ближе к центру), тем цена выше. Но близость к центру не является доминирующей составляющей цены, лишь ее частью

# %% [markdown]
# #### Цена - дата размещения

# %% [markdown]
# **Цена - день недели**

# %%
df_clean_day_week = df_clean.pivot_table(index='day_exposition_first',
                                         values='last_price',
                                         aggfunc=['median','count'])

# %%
df_clean_day_week
# Out:
#                          median      count
#                      last_price last_price
# day_exposition_first
# Friday                      5.0       1158
# Monday                      5.0       1108
# Saturday                    5.0        560
# Sunday                      4.9        478
# Thursday                    5.0       1302
# Tuesday                     5.1       1340
# Wednesday                   4.9       1171

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Большего всего покупок совершено во вторник и четверг. Понедельник, среда, пятница - чуть поменьше.
#   Возможно риэлторы в понедельник, среду, пятницу больше занимаются оформлением документов, а во вторник и четверг больше закрывают сделок.
# - Меньше всего в выходные дни, оно и понятно: люди отдыхают.
# - Медианная стоимость не связана с днем недели, всегда примерно одинаковая

# %% [markdown]
# **Цена - месяц**

# %%
df_clean_month_pivot = df_clean.pivot_table(index='month_exposition_first',
                                            values='last_price',
                                            aggfunc=['median','count'])

# %%
df_clean_month_pivot
# Out:
#                            median      count
#                        last_price last_price
# month_exposition_first
# 1                             5.0        426
# 2                             5.0        854
# 3                             4.8        693
# 4                             5.0        479
# 5                             5.0        339
# 6                             5.0        474
# 7                             5.1        577
# 8                             5.0        661
# 9                             5.0        650
# 10                            4.9        741
# 11                            5.0        762
# 12                            5.1        461

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# -  В январе меньше, чем в декабре. Это понятно - тяжелые праздники и выходные. Зато в феврале резкая активация продаж - отрабатывают предыдущие два месяца. Далее с марта по май - успокаиваются продажи, начинаются отпуска у людей, майские праздники. С мая начинается плавное увеличение продаж, вплоть до ноября, а в декабре резкий спад в 2 раза. Видимо люди начали готовиться к Новому году и отложили продажи.
# - Пик продаж - это период с августа по ноябрь.

# %% [markdown]
# **Цена - год**

# %%
df_clean_year_pivot = df_clean.pivot_table(index='year_exposition_first',
                                           values='last_price',
                                           aggfunc=['median','count'])

# %%
df_clean_year_pivot
# Out:
#                           median      count
#                       last_price last_price
# year_exposition_first
# 2015                         5.2        112
# 2016                         5.1        553
# 2017                         4.9       2582
# 2018                         5.0       3270
# 2019                         5.2        600

# %%
df_clean_year_pivot['median'].plot(figsize=(15,2));
plt.xlabel('Год')
plt.ylabel('Стоимость квартиры')
plt.title('Медианная стоимость квартир по годам')
plt.show()

df_clean_year_pivot['count'].plot(figsize=(15,2));
plt.xlabel('Год')
plt.ylabel('Продажи квартир')
plt.title('Количество продаж квартир по годам')
plt.show()

# %% [markdown]
# *Сколько месяцев продаж в 2019 в данных?*

# %%
df_clean.query('year_exposition_first == 2019')['month_exposition_first'].max()
# Out:
# 5

# %% [markdown]
# *Всего 5 месяцев. Давайте посмотрим на количество продаж по годам за первые 5 месяцев, чтобы примерно сравнить уровень продлаж в 2019г*

# %%
df_clean.query('month_exposition_first <= 5')['year_exposition_first'].value_counts()
# Out:
# 2018    1249
# 2017     621
# 2019     600
# 2016     311
# 2015      10
# Name: year_exposition_first, dtype: int64

# %% [markdown]
# *2019 год идет на уровне 2017г.*

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - В 2015 возможно сказались санкции из-за аннексии Крыма, что притормозило рынок недвижимости. ЦБ повысил ключевую ставку до 17%, выросла валюта.
# - В 2016 начал рынок по-тихонечку приходить в себя.
# - В 2017 -2018 растет покупательская способность и спрос, строится большое количество новостроек, возможно некачественных, зато недорогих.
# - В 2019 - Данные есть только за 5 месяцев, но уровень продаж идет как в 2017г. Интересно, будет ли увеличение продаж к концу года как в 2017г?.

# %% [markdown]
# **Создадим новый датафрейм с основными метриками, которые возможно оказывают влияние на цену квартиры**

# %%
df_clean_corr = df_clean[['last_price',
                        'rooms',
                        'total_area',
                        'floor',
                        'city_centers_nearest',
                        'month_exposition_first',
                        'year_exposition_first']]

# %% [markdown]
# *Построим матрицу корреляции*

# %%
corrMatrix = df_clean_corr.corr()
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow0_col0 {
#             background-color:  #b40426;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow0_col1 {
#             background-color:  #f2cbb7;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow0_col2 {
#             background-color:  #e67259;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow0_col3 {
#             background-color:  #84a7fc;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow0_col4 {
#             background-color:  #3b4cc0;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow0_col5 {
#             background-color:  #82a6fb;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow0_col6 {
#             background-color:  #82a6fb;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow1_col0 {
#             background-color:  #f6bda2;
#         }    #T_a24a0aa8_cce1_11ec_9dce_5404a6b20cacrow1_col1 {
#             background-color:  #b40426;
# ...

# %% [markdown]
# *Построим попарные диаграммы рассеивания для все метрик*

# %%
pd.plotting.scatter_matrix(df_clean_corr, figsize=(12,12));

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - По попарной диаграмме видна прямая зависимость цены от общей площади.
# - Есть зависимость у цены с количеством комнат, но после 4 комнат связь теряется.
# - Связи с этажностью дома низкая, но бОльшее количество дорогих сделок наблюдается в домах этажностью до 10.
# - Связи с удаленность от центра почти нет, но заметна область основных сделок на расстоянии от 5 до 18км от центра. Чем дальше, тем цена остается на уровне 5 млн
# - Связи с месяцами есть, не совсем конечно показательно, но видно, что продаж в середине года меньше
# - Количество продаж в 17 и 18 годах преобладают

# %% [markdown]
# ### Квартиры в Санкт-Петербурге и в его центре

# %% [markdown]
# *Выделим квартиры в Санкт-Петербургею Столбец 'Удаленность от центра' у нас уже переведен в км и целочисленный тип*

# %%
df_clean_piter = (df_clean
                    .query('locality_name == "Санкт-Петербург"')
                    .reset_index(drop=True)
                 )

# %%
df_clean_piter['city_centers_nearest'].describe()
# Out:
# count    6780.000000
# mean       12.285103
# std         4.285908
# min         0.300000
# 25%        10.000000
# 50%        12.800000
# 75%        15.100000
# max        26.100000
# Name: city_centers_nearest, dtype: float64

# %%
df_clean_piter.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0             2        10.0       100.0           2018-06-19      2
# 1            18         5.4        61.0           2017-02-26      3
# 2             5         5.0        39.6           2017-11-16      1
# 3            11         6.7        82.0           2017-11-23      3
# 4             8         3.2        31.0           2017-01-27      1
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            3.03            14         32.0     13          NaN   False
# 1            2.50             9         43.6      7          NaN   False
# 2            2.67            12         20.3      3          NaN   False
# 3            3.05             5         55.6      1          NaN   False
# 4            2.50             5         19.4      2          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# *Подсчитаем среднюю стоимость одного км удаленности от центра. Некоторая недвижимость находится непосредственно рядом с парков и имеет расстояние, равное 0. Это нужно учесть.*

# %%
df_clean_piter_without_0 = (df_clean_piter
                            .query('city_centers_nearest != 0')
                            .reset_index(drop=True)
                           )

# %%
df_clean_piter_without_0['price_km'] = (
    round(df_clean_piter_without_0['last_price'] / df_clean_piter_without_0['city_centers_nearest'],2)
)

# %%
df_clean_piter_without_0['price_km'].describe()
# Out:
# count    6780.000000
# mean        0.665394
# std         1.092265
# min         0.090000
# 25%         0.300000
# 50%         0.400000
# 75%         0.620000
# max        32.000000
# Name: price_km, dtype: float64

# %%
df_clean_piter_without_0['price_km'].value_counts().head()
# Out:
# 0.31    215
# 0.28    192
# 0.32    187
# 0.35    174
# 0.30    174
# Name: price_km, dtype: int64

# %%
price_km_mean = df_clean_piter_without_0['price_km'].mean()

# %%
print(f'Средняя цена для каждого километра составляет {int(price_km_mean*1000000)} руб')
# Out:
# Средняя цена для каждого километра составляет 665393 руб

# %% [markdown]
# **Построим график изменения цены за 1км от удаленности от центра**

# %%
df1 = df_clean_piter_without_0.pivot_table(index='city_centers_nearest', values='price_km')

# %% [markdown]
# *Для построения графика создадим новый столбец с расстоянием, таким же как сейчас индекс*

# %%
df1['city_centers_nearest'] = df1.index

# %%
df1.plot(x='city_centers_nearest',
         y='price_km',
         kind='scatter',
         grid=True)
plt.xlabel('Удаленность от центра, км')
plt.ylabel('Стоимость квартиры')
plt.title('Зависимость изменения цены за 1км от удаленности от центра')
plt.show()

# %%
df1.plot(x='city_centers_nearest',
         y='price_km',
         kind='hexbin',
         gridsize=15,
         sharex=False,
         grid=True)
plt.xlabel('Удаленность от центра, км')
plt.ylabel('Стоимость квартиры')
plt.title('Зависимость изменения цены за 1км от удаленности от центра')
plt.show()

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - График резко идет вниз до 5, далее снижение замедляется до 10 и дальше идет плавное однообразное снижение. **Сегмент от 0 до 5 км можно считать областью, входящей в центр**. В этой области резко падает стоимость квартир с удалением на каждый км.
# - Средняя цена для каждого километра составляет 665 393 руб

# %% [markdown]
# #### Изучим недвижимость в центре, сравним с остальной частью города

# %% [markdown]
# Выделим сегмент квартир в центре. Проанализируем эту территорию и изучим следующие параметры: площадь, цена, число комнат, высота потолков. Также выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Отличаются ли выводы от общих выводов по всему городу?

# %% [markdown]
# ##### Площадь центр - площадь город

# %%
flat_city_centre = df_clean_piter.query('0 <= city_centers_nearest <=5')

# %%
print(f'В центре у нас находится {flat_city_centre.shape[0]} шт недвижимости')
# Out:
# В центре у нас находится 566 шт недвижимости

# %%
flat_city_centre['living_area'].describe()
# Out:
# count    535.000000
# mean      41.405869
# std       16.926887
# min        6.000000
# 25%       28.650000
# 50%       40.000000
# 75%       54.000000
# max       88.000000
# Name: living_area, dtype: float64

# %%
flat_city_centre['living_area'].value_counts().head(5)
# Out:
# 30.0    9
# 40.0    8
# 16.0    8
# 25.0    8
# 34.0    7
# Name: living_area, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - В центре представлена недвижимость до 88 м2. Самое востребованное - 30м2, 9 объявлений. Очень мало объявлений. Похоже в самом центре никто расставаться с недвижимостью не торопится.

# %% [markdown]
# *Сравним площади в центре и в остальной части города*

# %%
df_clean_piter_without_centre = df_clean_piter.query('city_centers_nearest > 5')

# %%
ax = flat_city_centre['living_area'].plot(kind='hist',
                                          y='count',
                                          linewidth=3,
                                          histtype='step',
                                          alpha=0.7,
                                          label='centr',
                                          range=(0,75),
                                          figsize=(15,5))
df_clean_piter_without_centre['living_area'].plot(kind='hist',
                                                  bins=15,
                                                  linewidth=3,
                                                  histtype='step',
                                                  y='count',
                                                  alpha=0.7, 
                                                  ax=ax,
                                                  label='city',
                                                  range=(0,75),
                                                  grid=True,
                                                  legend=True,
                                                  figsize=(15,5))
plt.xlabel('Площадь квартиры')
plt.ylabel('Частота использования')
plt.title('Сравнение частоты площади квартир в центре и в остальной части города')
plt.show()

# %%
df_clean_piter_without_centre['living_area'].value_counts().head()
# Out:
# 18.0    250
# 20.0    184
# 17.0    164
# 30.0    153
# 16.0    132
# Name: living_area, dtype: int64

# %%
df_clean_piter_without_centre['living_area'].describe()
# Out:
# count    5882.000000
# mean       30.205186
# std        12.399371
# min         2.000000
# 25%        18.500000
# 50%        29.200000
# 75%        38.900000
# max        89.100006
# Name: living_area, dtype: float64

# %%
df_clean_piter_without_centre.query('living_area == 18')['airports_nearest'].median()
# Out:
# 31.5

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Самая востребованная площадь во всем городе - 18 м2 примерно в 32 км от центра. В центре покупают больше недвижимоть площадью 30м2. Если кто-то покупает в центре, значит может позволить себе больше квадратных метров, нежели тот, кто покупает в 30км от центра.

# %% [markdown]
# ##### Цена центр - цена город

# %%
flat_city_centre['last_price'].describe()
# Out:
# count    566.000000
# mean       7.685159
# std        2.253389
# min        1.600000
# 25%        6.000000
# 50%        7.500000
# 75%        9.375000
# max       12.500000
# Name: last_price, dtype: float64

# %%
flat_city_centre['last_price'].value_counts().head(5)
# Out:
# 8.0     17
# 8.5     16
# 7.5     16
# 6.0     16
# 10.0    15
# Name: last_price, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Средняя стоимость недвижимости в центре составляет 7,6 млн. Самая частая стоимость - 8 млн. Максимальная стоимость - 12,5 млн.

# %% [markdown]
# *Сравним цены в центре и в остальной части города*

# %%
ax = flat_city_centre['last_price'].plot(kind='hist',
                                         bins=15,
                                         y='count',
                                         linewidth=3,
                                         histtype='step',
                                         alpha=0.7,
                                         label='centr',
                                         range=(0,15),
                                         figsize=(15,5))
df_clean_piter_without_centre['last_price'].plot(kind='hist',
                                                 bins=15,
                                                 linewidth=3,
                                                 histtype='step',
                                                 y='count', 
                                                 alpha=0.7,
                                                 ax=ax, 
                                                 label='city',
                                                 range=(0,15),
                                                 grid=True,
                                                 legend=True,
                                                 figsize=(15,5))
plt.xlabel('Стоимость квартиры')
plt.ylabel('Частота использования')
plt.title('Сравнение стоимости квартир в центре и в остальной части города')
plt.show()

# %%
df_clean_piter_without_centre['last_price'].describe()
# Out:
# count    6214.000000
# mean        5.409237
# std         1.993419
# min         1.200000
# 25%         4.000000
# 50%         4.900000
# 75%         6.400000
# max        12.500000
# Name: last_price, dtype: float64

# %%
df_clean_piter_without_centre['last_price'].value_counts().head()
# Out:
# 4.0    216
# 3.6    215
# 4.2    214
# 3.8    211
# 4.6    205
# Name: last_price, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# Самая частая цена во всем городе - 4 млн, что в 2 раза меньше самой распространенной стоимости в центре. Что, вполне, соответствует действительности.

# %% [markdown]
# ##### Число комнат центр - число комнат город

# %%
flat_city_centre['rooms'].describe()
# Out:
# count    566.000000
# mean       2.494700
# std        1.017966
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        6.000000
# Name: rooms, dtype: float64

# %%
flat_city_centre['rooms'].value_counts().head(5)
# Out:
# 2    206
# 3    179
# 1     87
# 4     75
# 5     14
# Name: rooms, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - В основном выставлены 2ки и 3ки.

# %% [markdown]
# Сравним число комнат в центре и в остальной части города

# %%
ax = flat_city_centre['rooms'].plot(kind='hist',
                                    bins=20,
                                    y='count',
                                    linewidth=3,
                                    histtype='step',
                                    alpha=0.7,
                                    label='centr',
                                    range=(0,5), 
                                    figsize=(15,5))
df_clean_piter_without_centre['rooms'].plot(kind='hist',
                                            bins=20, 
                                            linewidth=3,
                                            histtype='step',
                                            y='count', 
                                            alpha=0.7,
                                            ax=ax, 
                                            label='city', 
                                            range=(0,5),
                                            grid=True, 
                                            legend=True, 
                                            figsize=(15,5))
plt.xlabel('Число комнат квартиры')
plt.ylabel('Частота использования')
plt.title('Сравнение числа комнат квартир в центре и в остальной части города')
plt.show()

# %%
df_clean_piter_without_centre['rooms'].describe()
# Out:
# count    6214.000000
# mean        1.912617
# std         0.878554
# min         0.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max         6.000000
# Name: rooms, dtype: float64

# %%
df_clean_piter_without_centre['rooms'].value_counts().head()
# Out:
# 1    2330
# 2    2197
# 3    1438
# 4     195
# 0      41
# Name: rooms, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Среднее число комнат в городе и в центре схожи - 2. Но, если в центре чаще продают 2ки и 3ки, то в остальной части города чаще продают 1ки и 2ки. Что соответствует распределению цен - в центре в 2 раза дороже.

# %% [markdown]
# ##### Высота потолков центр - высота потолков город

# %%
flat_city_centre['ceiling_height'].describe()
# Out:
# count    566.000000
# mean       3.018445
# std        0.257953
# min        2.400000
# 25%        2.800000
# 50%        3.000000
# 75%        3.200000
# max        3.500000
# Name: ceiling_height, dtype: float64

# %%
flat_city_centre['ceiling_height'].value_counts().head(5)
# Out:
# 3.0    109
# 3.2     55
# 2.8     36
# 3.5     32
# 3.1     31
# Name: ceiling_height, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Основная высота потолков в центре - 3м.

# %% [markdown]
# *Сравним высоту потолков в центре и в остальной части города*

# %%
ax = flat_city_centre['ceiling_height'].plot(kind='hist',
                                             bins=10,
                                             y='count',
                                             linewidth=3, 
                                             histtype='step',
                                             alpha=0.7, 
                                             label='centr',
                                             range=(2,4),
                                             figsize=(15,5))
df_clean_piter_without_centre['ceiling_height'].plot(kind='hist',
                                                     bins=10, 
                                                     linewidth=3, 
                                                     histtype='step', 
                                                     y='count', 
                                                     alpha=0.7, 
                                                     ax=ax, 
                                                     label='city', 
                                                     range=(2,4), 
                                                     grid=True, 
                                                     legend=True, 
                                                     figsize=(15,5))
plt.xlabel('Высота потолков квартиры')
plt.ylabel('Частота использования')
plt.title('Сравнение высоты потолков квартир в центре и в остальной части города')
plt.show()

# %%
df_clean_piter_without_centre['ceiling_height'].describe()
# Out:
# count    6214.000000
# mean        2.662399
# std         0.174401
# min         2.300000
# 25%         2.500000
# 50%         2.600000
# 75%         2.750000
# max         3.500000
# Name: ceiling_height, dtype: float64

# %%
df_clean_piter_without_centre['ceiling_height'].value_counts().head()
# Out:
# 2.50    1623
# 2.60     782
# 2.70     744
# 2.55     497
# 2.80     473
# Name: ceiling_height, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Основная высота потолков в городе - 2.5 - 2.6м., что меньше, чем в центре. Чем выше потолки, тем больше пространства в квартире и тем дороже она становится. Это соответствует ценам в центре и в остальном городе.

# %% [markdown]
# #### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# **Недвижимость в центре отличается от недвижимоти остальной части города**
#
# - Самое востребованное площадь в центре - 30м2, тогда как в городе - 18 м2. Видимо у тех, кто покупает в центре, достаточно денег на более большую площадь
#
#
# - Средняя стоимость недвижимости в центре составляет 7,6 млн, а в городе 5,4.
# Самая частая цена по городе - 4 млн, что в 2 раза меньше самой распространенной стоимости в центре 8млн. Что, вполне, соответствует действительности.
#
#
# - Среднее число комнат в городе и в центре схожи - 2. Но, если в центре чаще продают 2ки и 3ки, то в остальной части города чаще продают 1ки и 2ки. Что соответствует распределению уровня цен и площадей.
#
#
# - Основная высота потолков в городе - 2.5 - 2.6м., что меньше, чем в центре, где высота 3м. Чем выше потолки, тем больше пространства в квартире и тем дороже она становится. Это соответствует ценам в центре и в остальном городе.
#
#
# **В центре продают недвижимость в среднем большей площади, с большим количеством комнат, большей высоты потолков и, соответственно, большей стоимостью**

# %% [markdown]
# #### Факторы влияния на цену в центре

# %%
factor_centre = flat_city_centre[['last_price',
                                  'living_area',
                                  'rooms',
                                  'floor',
                                  'floor_flat',
                                  'city_centers_nearest',
                                  'day_exposition_first',
                                  'month_exposition_first',
                                  'year_exposition_first']]

# %%
corrMatrix = factor_centre.corr()
corrMatrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow0_col0 {
#             background-color:  #b40426;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow0_col1 {
#             background-color:  #f5c4ac;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow0_col2 {
#             background-color:  #e3d9d3;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow0_col3 {
#             background-color:  #90b2fe;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow0_col4 {
#             background-color:  #465ecf;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow0_col5 {
#             background-color:  #688aef;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow0_col6 {
#             background-color:  #85a8fc;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow1_col0 {
#             background-color:  #f3c7b1;
#         }    #T_ab3aa190_cce1_11ec_ba85_5404a6b20cacrow1_col1 {
#             background-color:  #b40426;
# ...

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Основной фактор, влияющий на цену - это площадь. Следующий фактор - число комнат. Дальше незначительное влияние оказывает этаж квартиры. Расстояние в центре особого влияния уже не оказывает, но есть небольшая отрицательная динамика корреляции

# %% [markdown]
# **Посмотрим на влияние этажа**

# %%
factor_centre_flat_pivot = factor_centre.pivot_table(index='floor_flat',
                                                     values='last_price',
                                                     aggfunc=['median','count'])
factor_centre_flat_pivot.columns = ['last_price_median','last_price_count']

# %%
factor_centre_flat_pivot.sort_values('last_price_count', ascending=False)
# Out:
#             last_price_median  last_price_count
# floor_flat
# другой                    7.7               342
# последний                 7.8               133
# первый                    6.2                91

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# Недвижимость на первом и последнем этажах покупают реже в 3 раз. Последний этаж более предпочтительнее первого. Первый этаж всегда считался хуже остальных: решетки на окнах, люди под окнами, под полом подвал, кошмар

# %% [markdown]
# **Посмотрим на влияние даты**

# %% [markdown]
# **Цена - день недели**

# %%
factor_centre_day_week = factor_centre.pivot_table(index='day_exposition_first',
                                                   values='last_price',
                                                   aggfunc=['median','count'])
factor_centre_day_week.columns = ['last_price_median', 'last_price_count']

# %%
factor_centre_day_week.sort_values('last_price_count', ascending=False)
# Out:
#                       last_price_median  last_price_count
# day_exposition_first
# Thursday                           7.30               116
# Tuesday                            7.60               111
# Friday                             8.00                94
# Monday                             7.60                91
# Wednesday                          7.45                88
# Saturday                           7.40                40
# Sunday                             7.90                26

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - Большего всего покупок совершено во вторник и четверг. Понедельник, среда, пятница - чуть поменьше.
#   Возможно риэлторы в понедельник, среду, пятницу больше занимаются оформлением документов, а во вторник и четверг больше закрывают сделок.
# - Меньше всего в выходные дни, оно и понятно: люди отдыхают.

# %% [markdown]
# **Цена - месяц**

# %%
factor_centre_month_pivot = factor_centre.pivot_table(index='month_exposition_first',
                                                      values='last_price',
                                                      aggfunc=['median','count'])
factor_centre_month_pivot.columns = ['last_price_median', 'last_price_count']

# %%
factor_centre_month_pivot
# Out:
#                         last_price_median  last_price_count
# month_exposition_first
# 1                                    8.40                37
# 2                                    8.00                57
# 3                                    7.60                47
# 4                                    7.45                34
# 5                                    7.50                25
# 6                                    7.25                42
# 7                                    8.00                57
# 8                                    7.25                60
# 9                                    8.00                50
# 10                                   7.10                42
# 11                                   7.15                68
# 12                                   7.40                47

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# -  В январе меньше, чем в декабре. Это понятно - тяжелые праздники и выходные. Зато в феврале резкая активация продаж - отрабатывают предыдущие два месяца. Далее с марта по май - успокаиваются продажи, начинаются отпуска у людей, майские праздники. С мая начинается плавное увеличение продаж, вплоть до ноября, с проседанием продаж в октябре, а в декабре резкий спад в 2 раза. Видимо люди начали готовиться к Новому году и отложили продажи.
# - Пик продаж - это период с июля по ноябрь.

# %% [markdown]
# **Цена - год**

# %%
factor_centre_year_pivot = factor_centre.pivot_table(index='year_exposition_first',
                                                     values='last_price',
                                                     aggfunc=['median','count'])

# %%
factor_centre_year_pivot
# Out:
#                           median      count
#                       last_price last_price
# year_exposition_first
# 2015                        6.25         16
# 2016                        8.30         48
# 2017                        7.50        224
# 2018                        7.50        247
# 2019                        8.00         31

# %%
factor_centre.query('month_exposition_first <= 5')['year_exposition_first'].value_counts()
# Out:
# 2018    91
# 2017    51
# 2019    31
# 2016    26
# 2015     1
# Name: year_exposition_first, dtype: int64

# %%
factor_centre['year_exposition_first'].value_counts()
# Out:
# 2018    247
# 2017    224
# 2016     48
# 2019     31
# 2015     16
# Name: year_exposition_first, dtype: int64

# %% [markdown]
#  <div style="border:solid black 2px; padding: 20px">
#
# - В 2015 возможно сказались санкции из-за аннексии Крыма, что притормозило рынок недвижимости. ЦБ повысил ключевую ставку до 17%, выросла валюта.
# - В 2016 начал рынок по-тихонечку приходить в себя.
# - В 2017 -2018 растет покупательская способность и спрос, строится большое количество новостроек, возможно некачественных, зато недорогих.
# - В 2019 - Данные есть только за 5 месяце, уровень продаж идет между 2016 и 2017г. 2017г прирос в 4 раза к концу года, прирастет ли также 2019 или останется на уровне 2016г?

# %% [markdown]
# #### Вывод

# %% [markdown]
#  <div style="border:solid indigo 4px; padding: 20px">
#
# ***На цену квартир в центре влияют следующие факторы***
#
# - **Основной фактор - это площадь**. Чем больше площадь, тем дороже недвижимость
#
#
# - **Следующий фактор - число комнат**. Число комнат коррелируется с площадью, так что увеличение комнат ожидаемо приводит к увеличению стоимости
#
#
# - Дальше **небольшое влияние оказывает этаж квартиры**.
# Недвижимость на первом и последнем этажах покупают реже в 3 раз. Последний этаж более предпочтительнее первого. Первый этаж всегда считался хуже остальных: решетки на окнах, люди под окнами, под полом подвал, кошмар
#
#
# - **Расстояние в центре особого влияния уже не оказывает**, но есть небольшая отрицательная динамика корреляции.
#
#
# - **День недели имеет значение**. Большего всего покупок совершено во **вторник и четверг**. Понедельник, среда, пятница - чуть поменьше. Возможно риэлторы в понедельник, среду, пятницу больше занимаются оформлением документов, а во вторник и четверг больше закрывают сделок. Меньше всего в выходные дни, оно и понятно: люди отдыхают.
#
#
# -  **Месяц года также имеет значение**. В январе меньше, чем в декабре. Это понятно - тяжелые праздники и выходные. Зато в феврале резкая активация продаж - отрабатывают предыдущие два месяца. Далее с марта по май - успокаиваются продажи, начинаются отпуска у людей, майские праздники. С мая начинается плавное увеличение продаж, вплоть до ноября, с проседанием продаж в октябре, а в декабре резкий спад в 2 раза. Видимо люди начали готовиться к Новому году и отложили продажи.**Пик продаж - это период с июля по ноябрь с проседанием продаж в октябре**
#
#
# - **Самые удачные года продаж - это 2017 и 2018**. Рост спроса и предложения. В 2019 - Данные есть только за 5 месяце, уровень продаж идет между 2016 и 2017г. 2017г прирос в 4 раза к концу года, прирастет ли также 2019 или останется на уровне 2016г пока неизвестно?

# %% [markdown]
# ## Общий вывод

# %% [markdown]
#  <div style="border:solid green 6px; padding: 20px">
#
# **Проведен анализ данных продаж недвижимости в Санкт-Петеребурге и его области.**
#
# **Целью анализа было выявление основных факторов, влияющих на цену недвижимости.**
#
# **Также проведено сравнение формирования цены в центре Санкт-Петеребурге и его остальной части**
#
# - Основная масса данных продаж в Санкт-Петербурге
#
#
# - Средняя стоимость недвижимости в центре составляет 7,6 млн, а в городе 5,4 млн.
# Самая частая цена по городе - 4 млн, что в 2 раза меньше самой распространенной стоимости в центре 8млн. Что, вполне, соответствует действительности.
#
#  **Выявлены следующие факторы, влияющие на цену**
#
#
# - ***Площадь недвижимости*** - это основной фактор, влияющий на цену. Коэффициент корреляции с ценой 0.8, что говорит о высокой связи цены с площадью. Чем больше площадь, тем больше и цена, что вполне логично. Самое востребованное площадь в центре - 30м2, тогда как в остальной части города - 18 м2. Видимо у тех, кто покупает в центре, достаточно денег на большую площадь.
#
#
# - ***Число комнат*** - это следующий фактор. Число комнат коррелируется с площадью, так что увеличение комнат ожидаемо приводит к увеличению стоимости. Среднее число комнат в городе и в центре схожи - 2. Но, если в центре чаще продают 2ки и 3ки, то в остальной части города чаще продают 1ки и 2ки. Что соответствует распределению уровня цен и площадей.
#
#
# - ***Удаленность от центра*** - имеет отрицательную корреляцию с ценой. Чем дальше от центра, тем недвижимость дешевле. Средняя цена для каждого километра составляет 665 393 руб.
#
#
# - ***Высота потолков***. Основная высота потолков в продаже - 2.5 - 2.6м., что меньше, чем в центре Петербурга, где средняя высота 3м. Чем выше потолки, тем больше пространства в квартире и тем дороже она становится. Это соответствует ценам в центре и в остальном городе.
#
#
# - ***Этаж недвижимости***. Недвижимость на первом и последнем этажах покупают реже в 6 раз. Последний этаж более предпочтительнее первого. Первый этаж всегда считался хуже остальных: решетки на окнах, люди под окнами, близость подвала.
#
#
# - ***Даты размещения***
# - В 2017 - 2018 максимальные продажи, тк растет покупательская способность и спрос, строится большое количество новостроек, возможно некачественных, зато недорогих.
# - В 2019 - Данные есть только за 5 месяцев, но уровень продаж идет как в 2017г. Интересно, будет ли увеличение продаж к концу года как в 2017г.
# - Пик продаж - это период с августа по ноябрь. Но в центре Петербурга есть провал в октябре. Возможно проходят ежегодные городские ярмарки или праздники, которые отвлекают покупателей и продавцов.
# - Большего всего покупок совершено во вторник и четверг. Понедельник, среда, пятница - чуть поменьше. Возможно риэлторы в понедельник, среду, пятницу больше занимаются оформлением документов, а во вторник и четверг больше закрывают сделок. Меньше всего в выходные дни, оно и понятно: люди отдыхают.
